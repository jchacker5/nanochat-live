# %% [markdown]
# # 🚀 SRGI Theory Validation - Complete Setup
#
# **Just run all cells! Everything is automated.**
#
# This notebook will:
# 1. ✅ Check GPU availability
# 2. ✅ Clone your repository
# 3. ✅ Install all dependencies
# 4. ✅ Run theory validation tests
# 5. ✅ Run EBM experiments
# 6. ✅ Train a small model to validate your theories
#
# **Time**: ~30-60 minutes on free T4 GPU
#
# ---
#
# ## 📋 Step 0: Enable GPU (IMPORTANT!)
#
# **Before running cells:**
# 1. Click **Runtime** → **Change runtime type**
# 2. Set **Hardware accelerator** to **GPU (T4)**
# 3. Click **Save**
#
# Then run all cells below!

# %%
# Check GPU availability
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("⚠️ No GPU detected. Enable GPU: Runtime > Change runtime type > GPU")

# %%
# Clone repository
# !git clone https://github.com/jchacker5/nanochat-live.git
# %cd nanochat-live

# %%
# Install all dependencies (this may take 5-10 minutes)
print("Installing PyTorch...")
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118 -q

print("Installing core dependencies...")
# !pip install datasets tokenizers tiktoken wandb numpy matplotlib pytest -q

print("Installing JAX and scientific libraries...")
# !pip install jax jaxlib equinox scipy -q

print("Installing THRML (EBM support)...")
# !pip install git+https://github.com/extropic-ai/thrml.git -q || echo "THRML installation failed, will use PyTorch fallback"

print("✅ All dependencies installed!")

# %% [markdown]
# ## Step 2: Build Rust Tokenizer (Optional - Skip if slow)

# %%
# Build Rust tokenizer (skip this cell if it takes too long - tokenizer is optional for theory tests)
# This may take 5-10 minutes
print("Installing Rust...")
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y > /dev/null 2>&1
import os
os.environ['PATH'] = os.environ.get('PATH', '') + ':' + os.path.expanduser('~/.cargo/bin')

print("Installing maturin...")
# !pip install maturin -q

print("Building Rust tokenizer...")
# !cd nanochat-live/rustbpe && maturin build --release > /dev/null 2>&1
# !pip install nanochat-live/rustbpe/target/wheels/*.whl -q

print("✅ Rust tokenizer built!")

# %% [markdown]
# ## Step 3: Run Theory Validation Tests

# %%
# Run SRGI theory validation - validates all 3 core principles
print("="*70)
print("Running SRGI Theory Validation Tests...")
print("="*70)
# !cd nanochat-live && python scripts/test_srgi_theory.py

# %%
# Run EBM experiments
# !python scripts/ebm_experiments.py
